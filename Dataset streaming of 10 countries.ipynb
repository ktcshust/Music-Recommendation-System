# %%
import requests
import numpy as np
import pandas as pd

# %%
standings_url = "https://kworb.net/spotify/country/nl_daily_totals.html"
data = requests.get(standings_url)
netherland = pd.read_html(data.text)[0]
netherland.head(700)
# Out:
#      Pos                   Artist and Title  Days    T10  Pk    (x?)  \
# 0      1    Davina Michelle - Duurt Te Lang  1301  142.0   1   (x59)
# 1      2       The Weeknd - Blinding Lights  1071  187.0   1   (x46)
# 2      3  Lewis Capaldi - Someone You Loved  1339   44.0   7     NaN
# 3      4          Ed Sheeran - Shape of You   989  148.0   1   (x68)
# 4      5         Tones And I - Dance Monkey   777  174.0   1  (x104)
# ..   ...                                ...   ...    ...  ..     ...
# 695  696               Sean Paul - Mad Love   184    NaN  19     NaN
# 696  697               Ali Gatie - It's You   234    NaN  38     NaN
# 697  698                     Ava Max - Salt   207    NaN  30     NaN
# 698  699                    Boef - ANTWOORD   135   32.0   1   (x10)
# 699  700         Armin van Buuren - Therapy   177    NaN  22     NaN
#
#      PkStreams     Total
# 0       445121  92745717
# 1       299351  87060564
# 2       180101  82016537
# 3       415302  77209274
# ...

# %%
netherland.insert(0, 'Country', 'Netherland')
netherland.head(700)
# Out:
#         Country  Pos                   Artist and Title  Days    T10  Pk  \
# 0    Netherland    1    Davina Michelle - Duurt Te Lang  1301  142.0   1
# 1    Netherland    2       The Weeknd - Blinding Lights  1071  187.0   1
# 2    Netherland    3  Lewis Capaldi - Someone You Loved  1339   44.0   7
# 3    Netherland    4          Ed Sheeran - Shape of You   989  148.0   1
# 4    Netherland    5         Tones And I - Dance Monkey   777  174.0   1
# ..          ...  ...                                ...   ...    ...  ..
# 695  Netherland  696               Sean Paul - Mad Love   184    NaN  19
# 696  Netherland  697               Ali Gatie - It's You   234    NaN  38
# 697  Netherland  698                     Ava Max - Salt   207    NaN  30
# 698  Netherland  699                    Boef - ANTWOORD   135   32.0   1
# 699  Netherland  700         Armin van Buuren - Therapy   177    NaN  22
#
#        (x?)  PkStreams     Total
# 0     (x59)     445121  92745717
# ...

# %%
standings_url = "https://kworb.net/spotify/country/kr_daily_totals.html"
data = requests.get(standings_url)
skr = pd.read_html(data.text)[0]
skr.head(700)
# Out:
#      Pos                                   Artist and Title  Days    T10  Pk  \
# 0      1                                       BTS - Butter   533  193.0   1
# 1      2                               The Kid LAROI - Stay   486  273.0   1
# 2      3                                    IVE - LOVE DIVE   216  193.0   1
# 3      4                            Justin Bieber - Peaches   597  166.0   1
# 4      5                                     BTS - Dynamite   644  181.0   1
# ..   ...                                                ...   ...    ...  ..
# 695  696  sokodomo - BE ! (Feat. Paloalto, lIlBOI) (Prod...    27    NaN  14
# 696  697                                  TREASURE - JIKJIN    45    NaN  81
# 697  698                         V - Christmas Tree - Inst.    47    NaN  54
# 698  699  SINCE - FACE TIME (Feat. GIRIBOY, pH-1, Gaeko)...    29    NaN  19
# 699  700                        Taylor Swift - Question...?    17    NaN  32
#
#       (x?)  PkStreams    Total
# ...

# %%
skr.insert(0, 'Country', 'South Korea')
skr.head(700)
# Out:
#          Country  Pos                                   Artist and Title  \
# 0    South Korea    1                                       BTS - Butter
# 1    South Korea    2                               The Kid LAROI - Stay
# 2    South Korea    3                                    IVE - LOVE DIVE
# 3    South Korea    4                            Justin Bieber - Peaches
# 4    South Korea    5                                     BTS - Dynamite
# ..           ...  ...                                                ...
# 695  South Korea  696  sokodomo - BE ! (Feat. Paloalto, lIlBOI) (Prod...
# 696  South Korea  697                                  TREASURE - JIKJIN
# 697  South Korea  698                         V - Christmas Tree - Inst.
# 698  South Korea  699  SINCE - FACE TIME (Feat. GIRIBOY, pH-1, Gaeko)...
# 699  South Korea  700                        Taylor Swift - Question...?
#
#      Days    T10  Pk   (x?)  PkStreams    Total
# ...

# %%
standings_url = "https://kworb.net/spotify/country/es_daily_totals.html"
data = requests.get(standings_url)
spain = pd.read_html(data.text)[0]
spain.head(700)
# Out:
#      Pos                                   Artist and Title  Days    T10  Pk  \
# 0      1                        Rauw Alejandro - Todo De Ti   534  147.0   1
# 1      2   Bizarrap - Quevedo: Bzrp Music Sessions, Vol. 52   124  123.0   1
# 2      3                           Danny Ocean - Me RehÃºso  1546  272.0   1
# 3      4                                     KAROL G - Tusa   752  170.0   1
# 4      5              C. Tangana - TÃº Me Dejaste De Querer   730  140.0   1
# ..   ...                                                ...   ...    ...  ..
# 695  696                               The Weeknd - Starboy   248   20.0   7
# 696  697  Morat - Yo Contigo, TÃº Conmigo - The Gong Gon...   281    NaN  15
# 697  698                                 Adele - Easy On Me   212    NaN  15
# 698  699                         Jennifer Lopez - El Anillo   171   20.0   7
# 699  700                              Sebastian Yatra - TBT   279    NaN  40
#
#        (x?)  PkStreams      Total
# ...

# %%
spain.insert(0, 'Country', 'Spain')
spain.head(700)
# Out:
#     Country  Pos                                   Artist and Title  Days  \
# 0     Spain    1                        Rauw Alejandro - Todo De Ti   534
# 1     Spain    2   Bizarrap - Quevedo: Bzrp Music Sessions, Vol. 52   124
# 2     Spain    3                           Danny Ocean - Me RehÃºso  1546
# 3     Spain    4                                     KAROL G - Tusa   752
# 4     Spain    5              C. Tangana - TÃº Me Dejaste De Querer   730
# ..      ...  ...                                                ...   ...
# 695   Spain  696                               The Weeknd - Starboy   248
# 696   Spain  697  Morat - Yo Contigo, TÃº Conmigo - The Gong Gon...   281
# 697   Spain  698                                 Adele - Easy On Me   212
# 698   Spain  699                         Jennifer Lopez - El Anillo   171
# 699   Spain  700                              Sebastian Yatra - TBT   279
#
#        T10  Pk    (x?)  PkStreams      Total
# ...

# %%
standings_url = "https://kworb.net/spotify/country/se_daily_totals.html"
data = requests.get(standings_url)
sweden = pd.read_html(data.text)[0]
sweden.head(700)
# Out:
#      Pos                                   Artist and Title  Days    T10  Pk  \
# 0      1                              Victor Leksell - Svag  1023  416.0   1
# 1      2                       The Weeknd - Blinding Lights  1069  297.0   1
# 2      3                               Avicii - Without You  1500  148.0   1
# 3      4                          Ed Sheeran - Shape of You   909  165.0   1
# 4      5                         Tones And I - Dance Monkey   892  226.0   1
# ..   ...                                                ...   ...    ...  ..
# 695  696                                     Ant Wan - 1942   274   15.0   3
# 696  697  Benny Anderssons Orkester - Nu tÃ¤ndas tusen j...   187    NaN  15
# 697  698                               Drake - Passionfruit   149   25.0   7
# 698  699                               P!nk - What About Us   199    NaN  16
# 699  700                 Thomas StenstrÃ¶m - Sista sommaren   198    3.0   7
#
#        (x?)  PkStreams      Total
# ...

# %%
sweden.insert(0, 'Country', 'Sweden')
sweden.head(700)
# Out:
#     Country  Pos                                   Artist and Title  Days  \
# 0    Sweden    1                              Victor Leksell - Svag  1023
# 1    Sweden    2                       The Weeknd - Blinding Lights  1069
# 2    Sweden    3                               Avicii - Without You  1500
# 3    Sweden    4                          Ed Sheeran - Shape of You   909
# 4    Sweden    5                         Tones And I - Dance Monkey   892
# ..      ...  ...                                                ...   ...
# 695  Sweden  696                                     Ant Wan - 1942   274
# 696  Sweden  697  Benny Anderssons Orkester - Nu tÃ¤ndas tusen j...   187
# 697  Sweden  698                               Drake - Passionfruit   149
# 698  Sweden  699                               P!nk - What About Us   199
# 699  Sweden  700                 Thomas StenstrÃ¶m - Sista sommaren   198
#
#        T10  Pk    (x?)  PkStreams      Total
# ...

# %%
standings_url = "https://kworb.net/spotify/country/us_daily_totals.html"
data = requests.get(standings_url)
us = pd.read_html(data.text)[0]
us.head(700)
# Out:
#      Pos                                   Artist and Title  Days    T10  Pk  \
# 0      1  Post Malone - Sunflower - Spider-Man: Into the...  1479  302.0   1
# 1      2                          Juice WRLD - Lucid Dreams  1644  178.0   1
# 2      3                       Lil Uzi Vert - XO TOUR Llif3  1852  212.0   1
# 3      4                             Post Malone - rockstar  1223  186.0   1
# 4      5                           J. Cole - No Role Modelz  2495    6.0   7
# ..   ...                                                ...   ...    ...  ..
# 695  696                           Lil Uzi Vert - New Patek   161   10.0   1
# 696  697                                    Flo Rida - GDFR   338   77.0   4
# 697  698                                   Logic - Everyday   185    8.0   4
# 698  699                           Marc E. Bassy - You & Me   214    NaN  16
# 699  700                          Billie Eilish - bellyache   257    NaN  39
#
#        (x?)  PkStreams      Total
# ...

# %%
us.insert(0, 'Country', 'USA')
us.head(1000)
# Out:
#     Country   Pos                                   Artist and Title  Days  \
# 0       USA     1  Post Malone - Sunflower - Spider-Man: Into the...  1479
# 1       USA     2                          Juice WRLD - Lucid Dreams  1644
# 2       USA     3                       Lil Uzi Vert - XO TOUR Llif3  1852
# 3       USA     4                             Post Malone - rockstar  1223
# 4       USA     5                           J. Cole - No Role Modelz  2495
# ..      ...   ...                                                ...   ...
# 995     USA   996                   The Chainsmokers - Call You Mine   125
# 996     USA   997                        Milky Chance - Stolen Dance   353
# 997     USA   998                              Echosmith - Cool Kids   274
# 998     USA   999                       Eminem - The Real Slim Shady   190
# 999     USA  1000                      A$AP Rocky - F**kin' Problems   528
#
#        T10   Pk    (x?)  PkStreams      Total
# ...

# %%
standings_url = "https://kworb.net/spotify/country/de_daily_totals.html"
data = requests.get(standings_url)
germany = pd.read_html(data.text)[0]
germany.head(1200)
# Out:
#        Pos                                   Artist and Title  Days    T10  \
# 0        1                                Apache 207 - Roller  1168  220.0
# 1        2                       The Weeknd - Blinding Lights  1061  165.0
# 2        3                         Tones And I - Dance Monkey   853  199.0
# 3        4                          Bonez MC - Ohne mein Team  2033  112.0
# 4        5                                  Bonez MC - 500 PS  1121  122.0
# ...    ...                                                ...   ...    ...
# 1195  1196                            Doja Cat - Need To Know   140    NaN
# 1196  1197                             Shirin David - Brillis    71    7.0
# 1197  1198                           Danny Ocean - Me RehÃºso   236    NaN
# 1198  1199  David Guetta - If You Really Love Me (How Will...   144    NaN
# 1199  1200                                   Ufo361 - Gib Gas    92   11.0
#
#       Pk   (x?)  PkStreams      Total
# ...

# %%
germany.insert(0, 'Country', 'Germany')
germany.head(1000)
# Out:
#      Country   Pos              Artist and Title  Days    T10  Pk   (x?)  \
# 0    Germany     1           Apache 207 - Roller  1168  220.0   1  (x97)
# 1    Germany     2  The Weeknd - Blinding Lights  1061  165.0   1   (x2)
# 2    Germany     3    Tones And I - Dance Monkey   853  199.0   2  (x28)
# 3    Germany     4     Bonez MC - Ohne mein Team  2033  112.0   3   (x9)
# 4    Germany     5             Bonez MC - 500 PS  1121  122.0   1  (x12)
# ..       ...   ...                           ...   ...    ...  ..    ...
# 995  Germany   996              Luciano - SHAWTY   145    7.0   2   (x2)
# 996  Germany   997       Sam Feldt - Post Malone   192    NaN  59    NaN
# 997  Germany   998         Capital Bra - Bye Bye   119    4.0   4    NaN
# 998  Germany   999                   Nimo - ZART   107    4.0   8    NaN
# 999  Germany  1000           Felix Jaehn - SICKO   146    NaN  51    NaN
#
#      PkStreams      Total
# 0      1357504  270545835
# 1       643705  202480959
# ...

# %%
standings_url = "https://kworb.net/spotify/country/sg_daily_totals.html"
data = requests.get(standings_url)
singapore = pd.read_html(data.text)[0]
singapore.head(1200)
# Out:
#        Pos                                   Artist and Title  Days    T10  \
# 0        1                James Arthur - Say You Won't Let Go  2236  155.0
# 1        2                          Ed Sheeran - Shape of You  1906  231.0
# 2        3  Eric Chou - ä½ ,å¥½ä¸å¥½? - Ending Theme Song...  2338    NaN
# 3        4                               Ed Sheeran - Perfect  2075  145.0
# 4        5                  Lewis Capaldi - Someone You Loved  1389  376.0
# ...    ...                                                ...   ...    ...
# 1195  1196                           Khalid - Know Your Worth   104    NaN
# 1196  1197                   Sam Smith - I'm Not The Only One    92   75.0
# 1197  1198                               Hael Husaini - Jampi   124    NaN
# 1198  1199                 Megan Thee Stallion - Savage Remix    84    NaN
# 1199  1200                              Harry Styles - Golden   120    NaN
#
#       Pk   (x?)  PkStreams     Total
# ...

# %%
singapore.insert(0, 'Country', 'Singapore')
singapore.head(1000)
# Out:
#        Country   Pos                                   Artist and Title  Days  \
# 0    Singapore     1                James Arthur - Say You Won't Let Go  2236
# 1    Singapore     2                          Ed Sheeran - Shape of You  1906
# 2    Singapore     3  Eric Chou - ä½ ,å¥½ä¸å¥½? - Ending Theme Song...  2338
# 3    Singapore     4                               Ed Sheeran - Perfect  2075
# 4    Singapore     5                  Lewis Capaldi - Someone You Loved  1389
# ..         ...   ...                                                ...   ...
# 995  Singapore   996                            Justin Bieber - Company   308
# 996  Singapore   997         FINNEAS - Let's Fall in Love for the Night   197
# 997  Singapore   998                      Hugh Jackman - The Other Side   108
# 998  Singapore   999                           Lady Gaga - Hold My Hand   119
# 999  Singapore  1000                         Charlie Puth - Marvin Gaye   317
#
# ...

# %%
standings_url = "https://kworb.net/spotify/country/gb_daily_totals.html"
data = requests.get(standings_url)
uk = pd.read_html(data.text)[0]
uk.head(1200)
# Out:
#        Pos                   Artist and Title  Days    T10  Pk    (x?)  \
# 0        1       The Killers - Mr. Brightside  2879    2.0   9     NaN
# 1        2  Lewis Capaldi - Someone You Loved  1405  283.0   1   (x26)
# 2        3          Ed Sheeran - Shape of You  1527  139.0   1   (x59)
# 3        4       The Weeknd - Blinding Lights  1072  237.0   1   (x70)
# 4        5                  Drake - One Dance  1548  162.0   1  (x101)
# ...    ...                                ...   ...    ...  ..     ...
# 1195  1196  Charli XCX - After the Afterparty   136    NaN  33     NaN
# 1196  1197        Dua Lipa - Kiss and Make Up    99    NaN  32     NaN
# 1197  1198      Lord Huron - The Night We Met   192    NaN  52     NaN
# 1198  1199        Benson Boone - In The Stars   142    NaN  18     NaN
# 1199  1200            Imagine Dragons - Enemy    88    NaN  15     NaN
#
#       PkStreams      Total
# 0        279141  242242339
# 1        667950  237025724
# 2       1322199  213122413
# ...

# %%
uk.insert(0, 'Country', 'United Kingdom')
uk.head(1000)
# Out:
#             Country   Pos                   Artist and Title  Days    T10  Pk  \
# 0    United Kingdom     1       The Killers - Mr. Brightside  2879    2.0   9
# 1    United Kingdom     2  Lewis Capaldi - Someone You Loved  1405  283.0   1
# 2    United Kingdom     3          Ed Sheeran - Shape of You  1527  139.0   1
# 3    United Kingdom     4       The Weeknd - Blinding Lights  1072  237.0   1
# 4    United Kingdom     5                  Drake - One Dance  1548  162.0   1
# ..              ...   ...                                ...   ...    ...  ..
# 995  United Kingdom   996               Matoma - False Alarm   193    NaN  34
# 996  United Kingdom   997           Imagine Dragons - Demons   541    NaN  54
# 997  United Kingdom   998      One Direction - Steal My Girl   195   69.0   2
# 998  United Kingdom   999  Krept & Konan - Freak Of The Week   250    NaN  14
# 999  United Kingdom  1000       Dermot Kennedy - Better Days   201    NaN  53
#
# ...

# %%
standings_url = "https://kworb.net/spotify/country/ca_daily_totals.html"
data = requests.get(standings_url)
canada = pd.read_html(data.text)[0]
canada.head(1200)
# Out:
#        Pos                                   Artist and Title  Days    T10  \
# 0        1  Post Malone - Sunflower - Spider-Man: Into the...  1475  237.0
# 1        2                       The Weeknd - Blinding Lights  1070  262.0
# 2        3                  Lewis Capaldi - Someone You Loved  1392  100.0
# 3        4                         Tones And I - Dance Monkey  1153  207.0
# 4        5                          Juice WRLD - Lucid Dreams  1589   88.0
# ...    ...                                                ...   ...    ...
# 1195  1196               Jonas Brothers - Like It's Christmas    82    NaN
# 1196  1197                The Weeknd - Is There Someone Else?    76    8.0
# 1197  1198                            Justin Bieber - As I Am    56   14.0
# 1198  1199                                 H.E.R. - Best Part   147    NaN
# 1199  1200                          blackbear - me & ur ghost   112    NaN
#
#       Pk   (x?)  PkStreams      Total
# ...

# %%
canada.insert(0, 'Country', 'Canada')
canada.head(1000)
# Out:
#     Country   Pos                                   Artist and Title  Days  \
# 0    Canada     1  Post Malone - Sunflower - Spider-Man: Into the...  1475
# 1    Canada     2                       The Weeknd - Blinding Lights  1070
# 2    Canada     3                  Lewis Capaldi - Someone You Loved  1392
# 3    Canada     4                         Tones And I - Dance Monkey  1153
# 4    Canada     5                          Juice WRLD - Lucid Dreams  1589
# ..      ...   ...                                                ...   ...
# 995  Canada   996  Frank Sinatra - Mistletoe And Holly - Remaster...   116
# 996  Canada   997                             The Weeknd - Sacrifice    88
# 997  Canada   998  benny blanco - I Canât Get Enough (benny bla...   104
# 998  Canada   999                        Kevin Gates - Really Really   358
# 999  Canada  1000                            Kanye West - Follow God    71
#
#        T10  Pk   (x?)  PkStreams      Total
# ...

# %%
standings_url = "https://kworb.net/spotify/country/br_daily_totals.html"
data = requests.get(standings_url)
brazil = pd.read_html(data.text)[0]
brazil.head(1200)
# Out:
#        Pos                                   Artist and Title  Days    T10  \
# 0        1           Henrique & Juliano - ArranhÃ£o - Ao Vivo   457  149.0
# 1        2                JoÃ£o Gomes - Meu PedaÃ§o de Pecado   502  124.0
# 2        3      Israel & Rodolffo - Batom de Cereja - Ao Vivo   430  130.0
# 3        4                 Matheus Fernandes - Baby Me Atende   527   94.0
# 4        5   George Henrique & Rodrigo - Vai LÃ¡ Em Casa Hoje   380  116.0
# ...    ...                                                ...   ...    ...
# 1195  1196                                Luan Santana - ILHA    97    NaN
# 1196  1197                      Sam Smith - How Do You Sleep?   125    NaN
# 1197  1198  LUDMILLA - ClichÃª (ParticipaÃ§Ã£o especial de...   138    NaN
# 1198  1199  JoÃ£o Neto & Frederico - Saudade do Caramba - ...   191    NaN
# 1199  1200                            Leo Santana - SÃ³ VocÃª   125    NaN
#
#       Pk   (x?)  PkStreams      Total
# ...

# %%
brazil.insert(0, 'Country', 'Brazil')
brazil.head(1000)
# Out:
#     Country   Pos                                  Artist and Title  Days  \
# 0    Brazil     1          Henrique & Juliano - ArranhÃ£o - Ao Vivo   457
# 1    Brazil     2               JoÃ£o Gomes - Meu PedaÃ§o de Pecado   502
# 2    Brazil     3     Israel & Rodolffo - Batom de Cereja - Ao Vivo   430
# 3    Brazil     4                Matheus Fernandes - Baby Me Atende   527
# 4    Brazil     5  George Henrique & Rodrigo - Vai LÃ¡ Em Casa Hoje   380
# ..      ...   ...                                               ...   ...
# 995  Brazil   996            MarÃ­lia MendonÃ§a - Impasse - Ao Vivo   357
# 996  Brazil   997                          Fifth Harmony - Worth It   593
# 997  Brazil   998                             Calvin Harris - Blame   638
# 998  Brazil   999                Gustavo Mioto - Despedida De Casal   164
# 999  Brazil  1000  JoÃ£o Bosco & Vinicius - Segunda TaÃ§a - Ao Vivo   128
#
#        T10  Pk    (x?)  PkStreams      Total
# ...

# %%
some_countries = pd.concat([netherland, sweden, skr, germany, canada, singapore, spain, us, brazil, uk])

# %%
some_countries
# Out:
#               Country    Pos                   Artist and Title  Days    T10  \
# 0          Netherland      1    Davina Michelle - Duurt Te Lang  1301  142.0
# 1          Netherland      2       The Weeknd - Blinding Lights  1071  187.0
# 2          Netherland      3  Lewis Capaldi - Someone You Loved  1339   44.0
# 3          Netherland      4          Ed Sheeran - Shape of You   989  148.0
# 4          Netherland      5         Tones And I - Dance Monkey   777  174.0
# ...               ...    ...                                ...   ...    ...
# 10283  United Kingdom  10284           Calvin Harris - Together     1    NaN
# 10284  United Kingdom  10285   Mallory Knox - Shout at the Moon     1    NaN
# 10285  United Kingdom  10286           Kim Cesarion - Undressed     1    NaN
# 10286  United Kingdom  10287              Ben Howard - Old Pine     1    NaN
# 10287  United Kingdom  10288           Gorgon City - Unmissable     1    NaN
#
#         Pk    (x?)  PkStreams     Total
# ...

# %%
dataset_of_10_countries = some_countries[['Country','Artist and Title','Pk','(x?)','PkStreams','Total']]

# %%
dataset_of_10_countries
# Out:
#               Country                   Artist and Title   Pk    (x?)  \
# 0          Netherland    Davina Michelle - Duurt Te Lang    1   (x59)
# 1          Netherland       The Weeknd - Blinding Lights    1   (x46)
# 2          Netherland  Lewis Capaldi - Someone You Loved    7     NaN
# 3          Netherland          Ed Sheeran - Shape of You    1   (x68)
# 4          Netherland         Tones And I - Dance Monkey    1  (x104)
# ...               ...                                ...  ...     ...
# 10283  United Kingdom           Calvin Harris - Together  188     NaN
# 10284  United Kingdom   Mallory Knox - Shout at the Moon  195     NaN
# 10285  United Kingdom           Kim Cesarion - Undressed  194     NaN
# 10286  United Kingdom              Ben Howard - Old Pine  189     NaN
# 10287  United Kingdom           Gorgon City - Unmissable  198     NaN
#
#        PkStreams     Total
# 0         445121  92745717
# 1         299351  87060564
# 2         180101  82016537
# ...

# %%
piv_1 = dataset_of_10_countries.pivot_table(index=['Country'], columns=['Artist and Title'], values='Total')

# %%
piv_1
# Out:
# Artist and Title  $NOT - Doja  $NOT - Whipski  $OHO BANI - INZIDANCE  \
# Country
# Brazil                    NaN             NaN                    NaN
# Canada               723768.0        426548.0                    NaN
# Germany              766558.0             NaN              6407367.0
# Netherland                NaN             NaN                    NaN
# Singapore                 NaN             NaN                    NaN
# South Korea               NaN             NaN                    NaN
# Spain                     NaN             NaN                    NaN
# Sweden                    NaN             NaN                    NaN
# USA                 5633307.0       2345511.0                    NaN
# United Kingdom            NaN             NaN                    NaN
#
# Artist and Title  $OHO BANI - KIDS  $OHO BANI - OLYMPIA  $OHO BANI - PLACEBO  \
# Country
# Brazil                         NaN                  NaN                  NaN
# ...

# %%
piv_2 = dataset_of_10_countries.pivot_table(index=['Artist and Title'], columns=['Country'], values='Total')

# %%
piv_2
# Out:
# Country                                             Brazil    Canada  \
# Artist and Title
# $NOT - Doja                                            NaN  723768.0
# $NOT - Whipski                                         NaN  426548.0
# $OHO BANI - INZIDANCE                                  NaN       NaN
# $OHO BANI - KIDS                                       NaN       NaN
# $OHO BANI - OLYMPIA                                    NaN       NaN
# ...                                                    ...       ...
# ì´ë°±ê¸¸ - ëì´ë¥¼ ë¨¹ëë¤ - Instrumental         NaN       NaN
# ì´ë°±ê¸¸ - ë¬ë¦°ë¤ ìë²ì§                        NaN       NaN
# ì´ë°±ê¸¸ - ì­ë
# ì ì ì´ë³´ì¬ì                  NaN       NaN
# ì´ë°±ê¸¸ - ì­ë
# ì ì ì´ë³´ì¬ì - Instrum...     NaN       NaN
# ì´ë°±ê¸¸ - ì­ë
# ì ì ì´ë³´ì¬ì - Remix V...     NaN       NaN
#
# Country                                               Germany  Netherland  \
# Artist and Title
# ...

# %%
piv_2[44000:47000]
# Out:
# Country                                               Brazil   Canada  \
# Artist and Title
# The Beatles - Across The Universe - Remastered ...   17390.0      NaN
# The Beatles - All You Need Is Love - Remastered     106371.0  32749.0
# The Beatles - Blackbird - Remastered                 69113.0  12921.0
# The Beatles - Can't Buy Me Love - Remastered             NaN      NaN
# The Beatles - Can't Buy Me Love - Remastered 2009    47910.0  11429.0
# ...                                                      ...      ...
# Vlad Reiser - Nakna i regnet                             NaN      NaN
# Vlad Reiser - PrankStar                                  NaN      NaN
# Vladimir Cauchemar - Aulos Reloaded                      NaN      NaN
# Voices of Winter - O Little Town of Bethlehem            NaN      NaN
# Volbeat - Battleship Chains                              NaN      NaN
#
# Country                                              Germany  Netherland  \
# Artist and Title
# ...

# %%
pd.dataset_of_10_countries.to_csv('10countries,csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17528/1984449753.py in <module>
# ----> 1 pd.dataset_of_10_countries.to_csv('10countries,csv')
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'dataset_of_10_countries'
